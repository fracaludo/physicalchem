# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# File paths
file_path = "/Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo/1 method.xlsx"
folder_path = '/Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo'

# Read the Excel file
df = pd.read_excel(file_path, sheet_name="normalised ", decimal=",")  

# Rename the first column to 'Wavelength'
df.rename(columns={df.columns[0]: "Wavelength"}, inplace=True)

# Color gradient
colors = plt.cm.Greens(np.linspace(0.2, 1, len(df.columns[1:])))

# Plot all europium concentrations
plt.figure(figsize=(10, 6))
for col, color in zip(df.columns[1:], colors):  # Skip the Wavelength column
    plt.plot(df["Wavelength"], df[col], label=f"{col} µM", color=color)

wavelength_to_add = 280  # Adding theoretical wavelength
plt.axvline(x=wavelength_to_add, color='gray', linewidth=1, label=f"{wavelength_to_add} nm")

# Customize the plot
plt.xlabel("Wavelength [nm]")
plt.ylabel("Intensity [a.u.]")
plt.title("Fluorescence Intensity vs. Wavelength for Different Eu³⁺ Concentrations F emission ")
plt.legend(title="Eu³⁺ Concentration [µM]", loc="upper left", bbox_to_anchor=(1, 1))
plt.tight_layout()  
plt.gca().set_facecolor('#f9f9f9')


# Saving the plot
def save_plot(directory, filename="Processed_Plot 1.png", format="png"):
    os.makedirs(directory, exist_ok=True)
    filepath = os.path.join(directory, filename)
    plt.savefig(filepath, format=format, dpi=600, bbox_inches="tight")
    print(f"Plot saved to: {filepath}")

save_plot(folder_path)


plt.show()
# Out:
# Plot saved to: /Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo/Processed_Plot 1.png

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os 

# File paths
file_path = "/Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo/2 method.xlsx"
folder_path = '/Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo'

# Read the Excel file
df = pd.read_excel(file_path, sheet_name="normalised ", decimal=",")  

# Rename the first column to 'Wavelength'
df.rename(columns={df.columns[0]: "Wavelength"}, inplace=True)

# Generate a color gradient 
colors = plt.cm.Greens(np.linspace(0.2,1, len(df.columns[1:])))

# Plot all europium concentrations
plt.figure(figsize=(10, 6))
for col, color in zip(df.columns[1:], colors):  # Skipping the Wavelength column
    plt.plot(df["Wavelength"], df[col], label=f"{col} µM", color=color)

wavelength_to_add = 320  # Adding theoretical wavelength
plt.axvline(x=wavelength_to_add, color='gray', linewidth=1, label=f"{wavelength_to_add} nm")

# Customize the plot
plt.xlabel("Wavelength [nm]")
plt.ylabel("Intensity [a.u.]")
plt.title("Fluorescence Intensity vs. Wavelength for Different Eu³⁺ Concentrations Y emission")
plt.legend(title="Eu³⁺ Concentration [µM]", loc="upper left", bbox_to_anchor=(1, 1))
plt.tight_layout()  
plt.gca().set_facecolor('#f9f9f9')

# Saving the plot
def save_plot(directory, filename="Processed_Plot 2.png", format="png"):
    os.makedirs(directory, exist_ok=True)
    filepath = os.path.join(directory, filename)
    plt.savefig(filepath, format=format, dpi=600, bbox_inches="tight")
    print(f"Plot saved to: {filepath}")

save_plot(folder_path)


plt.show()
# Out:
# Plot saved to: /Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo/Processed_Plot 2.png

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# File paths
file_path = "/Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo/3 method.xlsx"
folder_path = '/Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo'

# Read the Excel file
df = pd.read_excel(file_path, sheet_name="normalised ", decimal=",")  

# Rename the first column to 'Wavelength'
df.rename(columns={df.columns[0]: "Wavelength"}, inplace=True)

# Generate a color gradient (shades of green)
colors = plt.cm.Greens(np.linspace(0.2,1, len(df.columns[1:])))

# Plot all europium concentrations
plt.figure(figsize=(10, 6))
for col, color in zip(df.columns[1:], colors):  # Skipping the Wavelength column
    plt.plot(df["Wavelength"], df[col], label=f"{col} µM", color=color)

wavelength_to_add = 250  # Adding theoretical wavelength
plt.axvline(x=wavelength_to_add, color='gray', linewidth=1, label=f"{wavelength_to_add} nm")

# Customize the plot
plt.xlabel("Wavelength [nm]")
plt.ylabel("Intensity [a.u.]")
plt.title("Fluorescence Intensity vs. Wavelength for Different Eu³⁺ Concentrations F excitation")
plt.legend(title="Eu³⁺ Concentration [µM]", loc="upper left", bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.gca().set_facecolor('#f9f9f9')  

# Saving the plot
def save_plot(directory, filename="Processed_Plot 3.png", format="png"):
    os.makedirs(directory, exist_ok=True)
    filepath = os.path.join(directory, filename)
    plt.savefig(filepath, format=format, dpi=600, bbox_inches="tight")
    print(f"Plot saved to: {filepath}")

save_plot(folder_path)

# Show the plot
plt.show()
# Out:
# Plot saved to: /Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo/Processed_Plot 3.png

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# File paths
file_path = "/Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo/4method.xlsx"
folder_path = '/Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo'

# Read the Excel file
df = pd.read_excel(file_path, sheet_name="normalised ", decimal=",")  

# Rename the first column to 'Wavelength'
df.rename(columns={df.columns[0]: "Wavelength"}, inplace=True)

# Generate a color gradient 
colors = plt.cm.Greens(np.linspace(0.2,1, len(df.columns[1:])))

# Plot all europium concentrations
plt.figure(figsize=(10, 6))
for col, color in zip(df.columns[1:], colors):  # Skipping the Wavelength column
    plt.plot(df["Wavelength"], df[col], label=f"{col} µM", color=color)

wavelength_to_add = 277  # Adding theoretical wavelength
plt.axvline(x=wavelength_to_add, color='gray', linewidth=1, label=f"{wavelength_to_add} nm")


# Customize the plot
plt.xlabel("Wavelength [nm]")
plt.ylabel("Intensity [a.u.]")
plt.title("Fluorescence Intensity vs. Wavelength for Different Eu³⁺ Concentrations Y excitation")
plt.legend(title="Eu³⁺ Concentration [µM]", loc="upper left", bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.gca().set_facecolor('#f9f9f9')  

# Saving the plot 
def save_plot(directory, filename="Processed_Plot 4.png", format="png"):
    os.makedirs(directory, exist_ok=True)
    filepath = os.path.join(directory, filename)
    plt.savefig(filepath, format=format, dpi=600, bbox_inches="tight")
    print(f"Plot saved to: {filepath}")

save_plot(folder_path)

# Show the plot
plt.show()
# Out:
# Plot saved to: /Users/ludovica/Documents/Bachelor/BA6/Physical Chemistry/Challenge A/Fluo/Processed_Plot 4.png
